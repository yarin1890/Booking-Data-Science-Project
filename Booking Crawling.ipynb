# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re
import pandas as pd
import datetime
import pdb
from threading import Thread
import time

# %% [markdown]
# Here we get the hotel's distance from the center, in kilometers, using regex - for the get_hotel_data function below

# %%
def get_distance_from_center(txt):
    if ("מ'" in txt):
        # https://stackoverflow.com/questions/4289331/how-to-extract-numbers-from-a-string-in-python # 
        distance_from_center = float(re.findall("\d+",txt)[0])
        return distance_from_center/1000
    elif ("." in txt):
        distance_from_center = float(re.findall("\d+\.\d+", txt)[0])
        return  distance_from_center
    else:
        distance_from_center = float(re.findall("\d+",txt)[0])
        return  distance_from_center

# %% [markdown]
# Here we get the hotel's data, and take care of end cases as needed.

# %%
def get_hotel_data(hotel):   
    
    hotel_name = hotel.find("div", {"class": "fcab3ed991"}).text

    try:
        preferred_hotel = (hotel.find("span", {"data-testid": "preferred-badge"})["data-testid"] == "preferred-badge")
        preferred_hotel = 1 
        
    except:
        preferred_hotel = 0

    stars_count = len(hotel.findAll("span", {"class": "b6dc9a9e69 adc357e4f1 fe621d6382"}))
    
    ## source : https://stackoverflow.com/questions/4703390/how-to-extract-a-floating-number-from-a-string ## 
    distance_from_center = get_distance_from_center(hotel.find("span", {"data-testid": "distance"}).text)

    try:
        hotel_price_txt = hotel.find("span", {"data-testid": "price-and-discounted-price"}).text            
        if (',' not in hotel_price_txt):     
            hotel_price = int(re.findall("\d+",hotel_price_txt)[0])
                   
        else:
            hotel_price = int(re.findall("\d+\,\d+",hotel_price_txt)[0].replace(",", ""))
                         
    except AttributeError:
        hotel_price = -1 

    try:
        available_rooms_txt = hotel.find("div", {"class": "cb1f9edcd4"}).text
        if ('אחד' in available_rooms_txt):
            available_rooms  = 1
        elif ( hotel_price == -1):
            available_rooms = 0 
        else:
            available_rooms  = int(re.findall("\d+",available_rooms_txt)[0])
                           
    except AttributeError:
        if (hotel_price == -1):
            available_rooms = -1
        else:
            available_rooms = 10   
    
    if (hotel.find("div", {"class": "b5cd09854e d10a6220b4"}) is not None):
        if (hotel.find("div", {"class": "b5cd09854e d10a6220b4"}).text == '10'):
            hotel_rating = 10
        else:
            # https://stackoverflow.com/questions/4289331/how-to-extract-numbers-from-a-string-in-python # 
            hotel_rating = float(re.findall("\d+\.\d+", hotel.find("div", {"class": "b5cd09854e d10a6220b4"}).text)[0])
    else:
        hotel_rating = 0 

    
    if (hotel.find("span", {"class": "e2f34d59b1"}) is not  None):
        new_hotel = 1
    else:
        new_hotel = 0

    if (hotel.find("div", {"class": "d8eab2cf7f c90c0a70d3 db63693c62"}) is not None):
        number_of_reviews_txt = hotel.find("div", {"class": "d8eab2cf7f c90c0a70d3 db63693c62"}).text
        if (',' not in number_of_reviews_txt): 
            number_of_reviews = int(re.findall("\d+",number_of_reviews_txt)[0])
        else:
            number_of_reviews = int(re.findall("\d+\,\d+",number_of_reviews_txt)[0].replace(",", ""))
    else:
        number_of_reviews = 0
   
    return hotel_name,preferred_hotel,stars_count,distance_from_center,available_rooms,hotel_price,hotel_rating,number_of_reviews,new_hotel

# %% [markdown]
#  In this function we are getting the data from the page we currently are at, using our get_hotel_data function for each hotel in the page.

# %%
def get_data_from_page(current_url,offset,checkin_date,header):

    # https://stackoverflow.com/questions/27652543/how-to-use-python-requests-to-fake-a-browser-visit-a-k-a-and-generate-user-agent ##
    response = requests.get(current_url,headers=header).content
    soup = BeautifulSoup(response,'html.parser')
    hotels = soup.select('div[data-testid="property-card"]')
    
    # Append to our lists the current hotel data for the whole page, as len(hotels) is the
    # number of hotels we found in the current page.
    for i in range(0,len(hotels)):
        hotel_name = [] 
        available_rooms = [] 
        hotel_price = [] 
        hotel_rating = []
        preferred_hotel = [] 
        number_of_reviews = [] 
        distance_from_center = [] 
        stars_count = []
        new_hotel = []
        hotel = hotels[i]
        hotel_name,preferred_hotel,stars_count,distance_from_center,available_rooms,hotel_price,hotel_rating,number_of_reviews,new_hotel = get_hotel_data(hotel)
        hotel_name_list.append(hotel_name)
        available_rooms_list.append(available_rooms)
        hotel_price_list.append(hotel_price)
        hotel_rating_list.append(hotel_rating)
        preferred_hotel_list.append(preferred_hotel)
        number_of_reviews_list.append(number_of_reviews)
        distance_from_center_list.append(distance_from_center)
        stars_count_list.append(stars_count)
        new_hotel_list.append(new_hotel)
        check_in_list.append(checkin_date)

    return

# %% [markdown]
# In this function we get the current day's current number of pages, and use a thread for each page in our current day.

# %%
def get_data_by_date(current_url,checkin_date):
        offset = 0
        ## https://stackoverflow.com/questions/27652543/how-to-use-python-requests-to-fake-a-browser-visit-a-k-a-and-generate-user-agent ## 
        header = { 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
                 , 'cookie' : '_pxhd=xbsf0AilS3%2FsN5aktJGHeB3e%2FApPn7gC0UZkzeBS77zSVfAOb-Cit-TPVhFdZsISdxeUleLAaDOLfV%2Feb4X9JA%3D%3D%3AmlkePGOdumzsURV0mqjXpGCmoAIhCmK6R1Cog5AAxrNdumJgBe7wgHqcjMS4Gq3HqkeXBLuxcPYuXqsAONpN-twu23o-KuXFSS6nRDDDbXk%3D; cors_js=1; _scid=2ad41565-bf13-4c03-bf92-64bccd96906a; _pxvid=5074dd7b-9adb-11ec-b46f-49675271437a; _pin_unauth=dWlkPVl6RXhaakV5WlRFdFlqSTVOeTAwTmpGaUxUaGpZVFF0WVdOaFpXUmxZekEwTkRCaw; FPID=FPID2.2.kPraKQ2KIBfEtDySAacKMvu1TSssQ24deUQKGybapCk%3D.1646302728; aff_ga=GA1.2.281928406.1648753197; _ga_A12345=GS1.1.1648805210.7.1.1648805210.0; _px_f394gi7Fvmc43dfg_user_id=ODlmZDdlOTAtZTczNC0xMWVjLTkxZjAtNmQ2OWI5MzMyNTQ1; bkng_sso_ses=eyJib29raW5nX2dsb2JhbCI6W3siaCI6InVzU2FTZzBJcUJIZ1kyQzhZRlp6OVptUEpkMGs4aC9kSklGVzZYazloSEEifV19; OptanonConsent=implicitConsentCountry=nonGDPR&implicitConsentDate=1667212467797; bkng_sso_session=e30; bkng_expired_hint=eyJib29raW5nX2dsb2JhbCI6W3sibG9naW5faGludCI6MzE0Njg4OTk2Mn1dfQ; xp=02UmFuZG9tSVYkc2RlIyh
        soup = BeautifulSoup(response.content,'html.parser')
    
        # Get the number of hotels to know how many pages we have in the current day
        number_of_hotels = int(re.findall("\d+",soup.find('div', {'class': 'efdb2b543b'}).text)[0])
        number_of_pages = int(number_of_hotels/25)  + (number_of_hotels % 25 > 0)

        url_pages_data_list_for_threads = [] 

        # Get the url's we need for the current day according to the number of pages we have.
        for i in range(0,number_of_pages):
            url_pages_data_list_for_threads.append([url,offset,checkin_date,header])
            offset = offset + 25
            url = current_url + "&offset=" + str(offset)
            
        threads = [] 
        
        # For each page, create a thread and start it, then wait for all of them to stop together with the .join() command.
        for unit in url_pages_data_list_for_threads:
            url,offset,checkin_date,header = unit

            thread = Thread(target=get_data_from_page, args=(url,offset,checkin_date,header))
            threads.append(thread)
            
        for thread in threads:
            thread.start()

        for thread in threads:
            thread.join()
        
        return

# %% [markdown]
# In this function, we calculate the needed dates according to the number of days we need, and then we get the information for each day using a thread.

# %%
def crawling(days):

    ## https://stackoverflow.com/questions/32490629/getting-todays-date-in-yyyy-mm-dd-in-python
    now = datetime.date.today()
    next_date  = now + datetime.timedelta(days = (days - 1))

    # https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
    daterange = pd.date_range(now, next_date)
    url_list = []
    
    ## Collecting all of the url's from first day until the destination day
    for single_date in daterange:
        checkin_date = single_date.strftime("%Y-%m-%d")
        checkout_date =  str(single_date.date() +  datetime.timedelta(days=1))
        url = 'https://www.booking.com/searchresults.he.html?label=gen173nr-1BCAEoggI46AdIM1gEaGqIAQGYAQ64ARfIAQzYAQHoAQGIAgGoAgO4ArnTtZ8GwAIB0gIkNTRlM2Y0YzUtODA4Ny00MDUyLWFiN2ItNGJmOGQ5YTg2NDJm2AIF4AIB&sid=f5a19a8a686a469519274b1b081f63b3&aid=304142&ss=%D7%90%D7%99%D7%9C%D7%AA%2C+%D7%99%D7%A9%D7%A8%D7%90%D7%9C&efdco=1&lang=he&src=index&checkin='+checkin_date+'&checkout='+checkout_date+'&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&nflt=ht_id%3D204&property_type=hotel'
        url_list.append([url,checkin_date])

    # https://www.pythontutorial.net/python-concurrency/python-threading/    
    threads = [] 

    for unit in url_list:
        url,checkin_date = unit
        thread = Thread(target=get_data_by_date, args=(url,checkin_date))
        threads.append(thread)
        
    i= 1 
    start_time = datetime.datetime.now() 
    for thread in threads:      
        print("Starting thread number "+ str(i) )
        thread.start()
        time.sleep(0.1)
        i = i+1
        
    j = 1     
    for thread in threads:      
        thread.join()  
        print("Finish thread number  "+ str(j))
        j= j+1  
    
    end_time = datetime.datetime.now()
    total_time = (end_time - start_time).seconds
    
    df = pd.DataFrame({
            "check_in" : check_in_list,
            "hotel_name" : hotel_name_list, 
            "available_rooms" : available_rooms_list,
            "hotel_price" : hotel_price_list,
            "hotel_rating" : hotel_rating_list,
            "preferred_hotel" : preferred_hotel_list, 
            "number_of_reviews" : number_of_reviews_list,
            "distance_from_center" : distance_from_center_list, 
            "stars_count" : stars_count_list,
            "new_hotel" : new_hotel_list,
            })    
    
    df.drop_duplicates(inplace=True)
    df2 = df.sort_values('check_in')
    
    df2 = df.iloc[:, :].reset_index(drop=True)
    
    print(f'Crawling has finished. Total time for crawling {days} days: ' + str(total_time) + "seconds.")

    return df2

# %%
if __name__ == "__main__":
    
    check_in_list = []
    hotel_name_list = [] 
    available_rooms_list = [] 
    hotel_price_list = [] 
    hotel_rating_list = []
    preferred_hotel_list = [] 
    number_of_reviews_list = [] 
    distance_from_center_list = [] 
    stars_count_list = [] 
    new_hotel_list = []
    
    # Crawl for the needed amount of days starting from today, and save all of the information in our empty lists above.
    df = crawling(365)
    
    df.to_csv('./CsvFolder/Hotels365Day.csv')
# Out:
# Starting thread number 1
# Starting thread number 2
# Starting thread number 3
# Starting thread number 4
# Starting thread number 5
# Starting thread number 6
# Starting thread number 7
# Starting thread number 8
# Starting thread number 9
# Starting thread number 10
# Starting thread number 11
# Starting thread number 12
# Starting thread number 13
# Starting thread number 14
# Starting thread number 15
# Starting thread number 16
# Starting thread number 17
# Starting thread number 18
# Starting thread number 19
# Starting thread number 20
# Starting thread number 21
# Starting thread number 22
# Starting thread number 23
# Starting thread number 24
# Starting thread number 25
# Starting thread number 26
# Starting thread number 27
# Starting thread number 28
# Starting thread number 29
# Starting thread number 30
# Starting thread number 31
# Starting thread number 32
# Starting thread number 33
# Starting thread number 34
# Starting thread number 35
# Starting thread number 36
# Starting thread number 37
# Starting thread number 38
# Starting thread number 39
# Starting thread number 40
# Starting thread number 41
# Starting thread number 42
# Starting thread number 43
# Starting thread number 44
# Starting thread number 45
# Starting thread number 46
# Starting thread number 47
# Starting thread number 48
# Starting thread number 49
# Starting thread number 50
# Starting thread number 51
# Starting thread number 52
# Starting thread number 53
# Starting thread number 54
# Starting thread number 55
# Starting thread number 56
# Starting thread number 57
# Starting thread number 58
# Starting thread number 59
# Starting thread number 60
# Starting thread number 61
# Starting thread number 62
# Starting thread number 63
# Starting thread number 64
# Starting thread number 65
# Starting thread number 66
# Starting thread number 67
# Starting thread number 68
# Starting thread number 69
# Starting thread number 70
# Starting thread number 71
# Starting thread number 72
# Starting thread number 73
# Starting thread number 74
# Starting thread number 75
# Starting thread number 76
# Starting thread number 77
# Starting thread number 78
# Starting thread number 79
# Starting thread number 80
# Starting thread number 81
# Starting thread number 82
# Starting thread number 83
# Starting thread number 84
# Starting thread number 85
# Starting thread number 86
# Starting thread number 87
# Starting thread number 88
# Starting thread number 89
# Starting thread number 90
# Starting thread number 91
# Starting thread number 92
# Starting thread number 93
# Starting thread number 94
# Starting thread number 95
# Starting thread number 96
# Starting thread number 97
# Starting thread number 98
# Starting thread number 99
# Starting thread number 100
# Starting thread number 101
# Starting thread number 102
# Starting thread number 103
# Starting thread number 104
# Starting thread number 105
# Starting thread number 106
# Starting thread number 107
# Starting thread number 108
# Starting thread number 109
# Starting thread number 110
# Starting thread number 111
# Starting thread number 112
# Starting thread number 113
# Starting thread number 114
# Starting thread number 115
# Starting thread number 116
# Starting thread number 117
# Starting thread number 118
# Starting thread number 273
# Starting thread number 274
# Starting thread number 275
# Starting thread number 276
# Starting thread number 277
# Starting thread number 278
# Starting thread number 279
# Starting thread number 280
# Starting thread number 281
# Starting thread number 282
# Starting thread number 283
# Starting thread number 284
# Starting thread number 285
# Starting thread number 286
# Starting thread number 287
# Starting thread number 288
# Starting thread number 289
# Starting thread number 290
# Starting thread number 291
# Starting thread number 292
# Starting thread number 293
# Starting thread number 294
# Starting thread number 295
# Starting thread number 296
# Starting thread number 297
# Starting thread number 298
# Starting thread number 299
# Starting thread number 300
# Starting thread number 301
# Starting thread number 302
# Starting thread number 303
# Starting thread number 304
# Starting thread number 305
# Starting thread number 306
# Starting thread number 307
# Starting thread number 308
# Starting thread number 309
# Starting thread number 310
# Starting thread number 311
# Starting thread number 312
# Starting thread number 313
# Starting thread number 314
# Starting thread number 315
# Starting thread number 316
# Starting thread number 317
# Starting thread number 318
# Starting thread number 319
# Starting thread number 320
# Starting thread number 321
# Starting thread number 322
# Starting thread number 323
# Starting thread number 324
# Starting thread number 325
# Starting thread number 326
# Starting thread number 327
# Starting thread number 328
# Starting thread number 329
# Starting thread number 330
# Starting thread number 331
# Starting thread number 332
# Starting thread number 333
# Starting thread number 334
# Starting thread number 335
# Starting thread number 336
# Starting thread number 337
# Starting thread number 338
# Starting thread number 339
# Starting thread number 340
# Starting thread number 341
# Starting thread number 342
# Starting thread number 343
# Starting thread number 344
# Starting thread number 345
# Starting thread number 346
# Starting thread number 347
# Starting thread number 348
# Starting thread number 349
# Starting thread number 350
# Starting thread number 351
# Starting thread number 352
# Starting thread number 353
# Starting thread number 354
# Starting thread number 355
# Starting thread number 356
# Starting thread number 357
# Starting thread number 358
# Starting thread number 359
# Starting thread number 360
# Starting thread number 361
# Starting thread number 362
# Starting thread number 363
# Starting thread number 364
# Starting thread number 365
# Finish thread number  1
# Finish thread number  2
# Finish thread number  3
# Finish thread number  4
# Finish thread number  5
# Finish thread number  6
# Finish thread number  7
# Finish thread number  8
# Finish thread number  9
# Finish thread number  10
# Finish thread number  11
# Finish thread number  12
# Finish thread number  13
# Finish thread number  14
# Finish thread number  15
# Finish thread number  16
# Finish thread number  17
# Finish thread number  18
# Finish thread number  19
# Finish thread number  20
# Finish thread number  21
# Finish thread number  22
# Finish thread number  23
# Finish thread number  24
# Finish thread number  25
# Finish thread number  26
# Finish thread number  27
# Finish thread number  28
# Finish thread number  29
# Finish thread number  30
# Finish thread number  31
# Finish thread number  32
# Finish thread number  33
# Finish thread number  34
# Finish thread number  35
# Finish thread number  36
# Finish thread number  37
# Finish thread number  38
# Finish thread number  39
# Finish thread number  40
# Finish thread number  41
# Finish thread number  42
# Finish thread number  43
# Finish thread number  44
# Finish thread number  45
# Finish thread number  46
# Finish thread number  47
# Finish thread number  48
# Finish thread number  49
# Finish thread number  50
# Finish thread number  51
# Finish thread number  52
# Finish thread number  53
# Finish thread number  54
# Finish thread number  55
# Finish thread number  56
# Finish thread number  57
# Finish thread number  58
# Finish thread number  59
# Finish thread number  60
# Finish thread number  61
# Finish thread number  62
# Finish thread number  63
# Finish thread number  64
# Finish thread number  65
# Finish thread number  66
# Finish thread number  67
# Finish thread number  68
# Finish thread number  69
# Finish thread number  70
# Finish thread number  71
# Finish thread number  72
# Finish thread number  73
# Finish thread number  74
# Finish thread number  75
# Finish thread number  76
# Finish thread number  77
# Finish thread number  78
# Finish thread number  79
# Finish thread number  80
# Finish thread number  81
# Finish thread number  82
# Finish thread number  83
# Finish thread number  84
# Finish thread number  85
# Finish thread number  86
# Finish thread number  87
# Finish thread number  88
# Finish thread number  89
# Finish thread number  90
# Finish thread number  91
# Finish thread number  92
# Finish thread number  93
# Finish thread number  94
# Finish thread number  95
# Finish thread number  96
# Finish thread number  97
# Finish thread number  98
# Finish thread number  99
# Finish thread number  100
# Finish thread number  101
# Finish thread number  102
# Finish thread number  103
# Finish thread number  104
# Finish thread number  105
# Finish thread number  106
# Finish thread number  107
# Finish thread number  108
# Finish thread number  109
# Finish thread number  110
# Finish thread number  111
# Finish thread number  112
# Finish thread number  113
# Finish thread number  114
# Finish thread number  115
# Finish thread number  116
# Finish thread number  117
# Finish thread number  118
# Finish thread number  119
# Finish thread number  120
# Finish thread number  121
# Finish thread number  122
# Finish thread number  123
# Finish thread number  124
# Finish thread number  125
# Finish thread number  126
# Finish thread number  127
# Finish thread number  128
# Finish thread number  129
# Finish thread number  130
# Finish thread number  131
# Finish thread number  132
# Finish thread number  133
# Finish thread number  134
# Finish thread number  135
# Finish thread number  136
# Finish thread number  137
# Finish thread number  138
# Finish thread number  139
# Finish thread number  140
# Finish thread number  141
# Finish thread number  142
# Finish thread number  143
# Finish thread number  144
# Finish thread number  145
# Finish thread number  146
# Finish thread number  147
# Finish thread number  148
# Finish thread number  149
# Finish thread number  150
# Finish thread number  151
# Finish thread number  152
# Finish thread number  153
# Finish thread number  154
# Finish thread number  155
# Finish thread number  156
# Finish thread number  157
# Finish thread number  158
# Finish thread number  159
# Finish thread number  160
# Finish thread number  161
# Finish thread number  162
# Finish thread number  163
# Finish thread number  164
# Finish thread number  165
# Finish thread number  166
# Finish thread number  167
# Finish thread number  168
# Finish thread number  169
# Finish thread number  170
# Finish thread number  171
# Finish thread number  172
# Finish thread number  173
# Finish thread number  174
# Finish thread number  175
# Finish thread number  176
# Finish thread number  177
# Finish thread number  178
# Finish thread number  179
# Finish thread number  180
# Finish thread number  181
# Finish thread number  182
# Finish thread number  183
# Finish thread number  184
# Finish thread number  185
# Finish thread number  186
# Finish thread number  187
# Finish thread number  188
# Finish thread number  189
# Finish thread number  190
# Finish thread number  191
# Finish thread number  192
# Finish thread number  193
# Finish thread number  194
# Finish thread number  195
# Finish thread number  196
# Finish thread number  197
# Finish thread number  198
# Finish thread number  199
# Finish thread number  200
# Finish thread number  201
# Finish thread number  202
# Finish thread number  203
# Finish thread number  204
# Finish thread number  205
# Finish thread number  206
# Finish thread number  207
# Finish thread number  208
# Finish thread number  209
# Finish thread number  210
# Finish thread number  211
# Finish thread number  212
# Finish thread number  213
# Finish thread number  214
# Finish thread number  215
# Finish thread number  216
# Finish thread number  217
# Finish thread number  218
# Finish thread number  219
# Finish thread number  220
# Finish thread number  221
# Finish thread number  222
# Finish thread number  223
# Finish thread number  224
# Finish thread number  225
# Finish thread number  226
# Finish thread number  227
# Finish thread number  228
# Finish thread number  229
# Finish thread number  230
# Finish thread number  231
# Finish thread number  232
# Finish thread number  233
# Finish thread number  234
# Finish thread number  235
# Finish thread number  236
# Finish thread number  237
# Finish thread number  238
# Finish thread number  239
# Finish thread number  240
# Finish thread number  241
# Finish thread number  242
# Finish thread number  243
# Finish thread number  244
# Finish thread number  245
# Finish thread number  246
# Finish thread number  247
# Finish thread number  248
# Finish thread number  249
# Finish thread number  250
# Finish thread number  251
# Finish thread number  252
# Finish thread number  253
# Finish thread number  254
# Finish thread number  255
# Finish thread number  256
# Finish thread number  257
# Finish thread number  258
# Finish thread number  259
# Finish thread number  260
# Finish thread number  261
# Finish thread number  262
# Finish thread number  263
# Finish thread number  264
# Finish thread number  265
# Finish thread number  266
# Finish thread number  267
# Finish thread number  268
# Finish thread number  269
# Finish thread number  270
# Finish thread number  271
# Finish thread number  272
# Finish thread number  273
# Finish thread number  274
# Finish thread number  275
# Finish thread number  276
# Finish thread number  277
# Finish thread number  278
# Finish thread number  279
# Finish thread number  280
# Finish thread number  281
# Finish thread number  282
# Finish thread number  283
# Finish thread number  284
# Finish thread number  285
# Finish thread number  286
# Finish thread number  287
# Finish thread number  288
# Finish thread number  289
# Finish thread number  290
# Finish thread number  291
# Finish thread number  292
# Finish thread number  293
# Finish thread number  294
# Finish thread number  295
# Finish thread number  296
# Finish thread number  297
# Finish thread number  298
# Finish thread number  299
# Finish thread number  300
# Finish thread number  301
# Finish thread number  302
# Finish thread number  303
# Finish thread number  304
# Finish thread number  305
# Finish thread number  306
# Finish thread number  307
# Finish thread number  308
# Finish thread number  309
# Finish thread number  310
# Finish thread number  311
# Finish thread number  312
# Finish thread number  313
# Finish thread number  314
# Finish thread number  315
# Finish thread number  316
# Finish thread number  317
# Finish thread number  318
# Finish thread number  319
# Finish thread number  320
# Finish thread number  321
# Finish thread number  322
# Finish thread number  323
# Finish thread number  324
# Finish thread number  325
# Finish thread number  326
# Finish thread number  327
# Finish thread number  328
# Finish thread number  329
# Finish thread number  330
# Finish thread number  331
# Finish thread number  332
# Finish thread number  333
# Finish thread number  334
# Finish thread number  335
# Finish thread number  336
# Finish thread number  337
# Finish thread number  338
# Finish thread number  339
# Finish thread number  340
# Finish thread number  341
# Finish thread number  342
# Finish thread number  343
# Finish thread number  344
# Finish thread number  345
# Finish thread number  346
# Finish thread number  347
# Finish thread number  348
# Finish thread number  349
# Finish thread number  350
# Finish thread number  351
# Finish thread number  352
# Finish thread number  353
# Finish thread number  354
# Finish thread number  355
# Finish thread number  356
# Finish thread number  357
# Finish thread number  358
# Finish thread number  359
# Finish thread number  360
# Finish thread number  361
# Finish thread number  362
# Finish thread number  363
# Finish thread number  364
# Finish thread number  365
# Crawling has finished. Total time for crawling 365 days: 313seconds.
